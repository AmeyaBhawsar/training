# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("automobile.png")

sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize = 3)   #Sobel for horizontal edges
sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize = 3)   #Sobel for vertical edges

combined_sobel = cv2.add(sobelx, sobely)

thresh, binary_sobel = cv2.threshold(combined_sobel, 120, 255, cv2.THRESH_BINARY)

plt.figure(figsize = (16, 8))
plt.subplot(1, 4, 1)
plt.title('Original Image')
plt.imshow(img, cmap = 'gray')
plt.subplot(1, 4, 2)
plt.title('Sobel X Image')
plt.imshow(sobelx, cmap = 'gray')
plt.subplot(1, 4, 3)
plt.title('Sobel Y Image')
plt.imshow(sobely, cmap = 'gray')
plt.subplot(1, 4, 4)
plt.title('Final Binary Sobel Image')
plt.imshow(binary_sobel, cmap = 'gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-767.0..788.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-873.0..972.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].

# %%
img = cv2.imread('automobile.png', 0) 

edges = cv2.Canny(img, 50, 150)  

cv2.imshow('Canny Images', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize = (16, 8))
plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(img, cmap = 'gray')
plt.subplot(1, 3, 2)
plt.title('Binary Sobel Image')
plt.imshow(binary_sobel, cmap = 'gray')
plt.subplot(1, 3, 3)
plt.title('Canny Image')
plt.imshow(edges, cmap = 'gray')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..255.0].
